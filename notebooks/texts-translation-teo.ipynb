# %%
from pathlib import Path

# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

import src.auth_utils  as au
import src.translation as tr

from dotenv import load_dotenv
load_dotenv('/home/teo/profile.env')
# Out:
# True

# %%
# groq_api_keys = au.get_secret("GROQ_API_KEYS").split(";")

# Other models to try here:
# https://console.groq.com/docs/models
GROQ_MODEL = "llama-3.1-70b-versatile"
# GROQ_MODEL = "llama-3.1-70b-specdec"

translator = tr.GroqTranslator(api_keys_var="GROQ_API_KEYS",
                               groq_model=GROQ_MODEL)
# Out:
# Returning secret from environment variable `GROQ_API_KEYS`=`gs...a9`

# %%
spanish_text = """Cuenta con estudiantes que, en un ambiente de formación integral, interdisciplinario y flexible, son el principal agente de su proceso educativo. Facilita que su cuerpo profesoral, altamente capacitado, desarrolle un proyecto de vida académica y profesional sobresaliente, para lo cual apoya una actividad investigativa que contribuye al desarrollo del país y a su proyección internacional."""

translator.translate(spanish_text, verbose=True)

# %%
file_prefix = "reglamento-maestria-web-2024"
input_lines = Path(f"../data/{file_prefix}.preprocessed.txt").read_text().split("\n")
print(f"{len(input_lines)} input lines ")
n_lines = len(input_lines)

with Path(f"../data/{file_prefix}.translated.txt").open("wt") as f_out:
    for i, line in enumerate(input_lines):
        print(f"{i+1:4d} / {n_lines} ({100.0 * (i+1)/n_lines:.1f}%)")
        line_translation = translator.translate(line)
        print(line_translation, file=f_out, flush=True)
# Out:
# 838 input lines
#    1 / 838 (0.1%)
#    2 / 838 (0.2%)
# Spanish text: ## REGLAMENTO G...LAMENTO GENERAL ...
# Found in cache!
#    3 / 838 (0.4%)
#    4 / 838 (0.5%)
# Spanish text: ## DE ESTUDIANT...TES DE MAESTRÍA ...
# Found in cache!
#    5 / 838 (0.6%)
#    6 / 838 (0.7%)
#    7 / 838 (0.8%)
# Spanish text: ## BOGOTÁ, D. C...# BOGOTÁ, D. C. ...
# Found in cache!
#    8 / 838 (1.0%)
#    9 / 838 (1.1%)
#   10 / 838 (1.2%)
#   11 / 838 (1.3%)
# Spanish text: La versión actu...uniandes.edu.co ...
# Found in cache!
#   12 / 838 (1.4%)
# Spanish text: ## MISIÓN...## MISIÓN ...
# Found in cache!
#   13 / 838 (1.6%)
#   14 / 838 (1.7%)
#   15 / 838 (1.8%)
#   16 / 838 (1.9%)
# Spanish text: ## VISIÓN...## VISIÓN ...
# Found in cache!
#   17 / 838 (2.0%)
#   18 / 838 (2.1%)
#   19 / 838 (2.3%)
#   20 / 838 (2.4%)
# Spanish text: ## VALORES...## VALORES ...
# Found in cache!
#   21 / 838 (2.5%)
#   22 / 838 (2.6%)
#   23 / 838 (2.7%)
#   24 / 838 (2.9%)
# Spanish text: ## PREÁMBULO...## PREÁMBULO ...
# Found in cache!
#   25 / 838 (3.0%)
#   26 / 838 (3.1%)
#   27 / 838 (3.2%)
#   28 / 838 (3.3%)
#   29 / 838 (3.5%)
#   30 / 838 (3.6%)
# Spanish text: # CAPÍTULO I. C...O DE APLICACIÓN ...
# Found in cache!
#   31 / 838 (3.7%)
#   32 / 838 (3.8%)
#   33 / 838 (3.9%)
#   34 / 838 (4.1%)
#   35 / 838 (4.2%)
#   36 / 838 (4.3%)
# Spanish text: # CAPÍTULO II. ...IZACIÓN GENERAL ...
# Found in cache!
#   37 / 838 (4.4%)
#   38 / 838 (4.5%)
#   39 / 838 (4.7%)
#   40 / 838 (4.8%)
#   41 / 838 (4.9%)
#   42 / 838 (5.0%)
# Spanish text: # CAPÍTULO III....O Y PERMANENCIA ...
# Found in cache!
#   43 / 838 (5.1%)
#   44 / 838 (5.3%)
#   45 / 838 (5.4%)
#   46 / 838 (5.5%)
# Spanish text: A. Ingreso regu...so regular					 ...
# Found in cache!
#   47 / 838 (5.6%)
# Spanish text: B. Ingreso por ...erencia interna ...
# Found in cache!
#   48 / 838 (5.7%)
# Spanish text: C. Ingreso por ...erencia externa ...
# Found in cache!
#   49 / 838 (5.8%)
#   50 / 838 (6.0%)
#   51 / 838 (6.1%)
# Spanish text: D. Permanencia...D. Permanencia ...
# Found in cache!
#   52 / 838 (6.2%)
#   53 / 838 (6.3%)
#   54 / 838 (6.4%)
# Spanish text: # CAPÍTULO IV. ...HOS PECUNIARIOS ...
# Found in cache!
#   55 / 838 (6.6%)
#   56 / 838 (6.7%)
#   57 / 838 (6.8%)
#   58 / 838 (6.9%)
#   59 / 838 (7.0%)
#   60 / 838 (7.2%)
# Spanish text: # CAPÍTULO V. D...ECHOS Y DEBERES ...
# Found in cache!
#   61 / 838 (7.3%)
#   62 / 838 (7.4%)
#   63 / 838 (7.5%)
#   64 / 838 (7.6%)
# Spanish text: A. Derechos...A. Derechos ...
# Found in cache!
#   65 / 838 (7.8%)
#   66 / 838 (7.9%)
#   67 / 838 (8.0%)
# Spanish text: B. Deberes...B. Deberes ...
# Found in cache!
#   68 / 838 (8.1%)
#   69 / 838 (8.2%)
#   70 / 838 (8.4%)
# Spanish text: # CAPÍTULO VI. ...IÓN ESTUDIANTIL ...
# Found in cache!
#   71 / 838 (8.5%)
#   72 / 838 (8.6%)
#   73 / 838 (8.7%)
#   74 / 838 (8.8%)
#   75 / 838 (8.9%)
#   76 / 838 (9.1%)
# Spanish text: # CAPÍTULO VII....GIMEN ACADÉMICO ...
# Found in cache!
#   77 / 838 (9.2%)
#   78 / 838 (9.3%)
# Spanish text: A. Asistencia a...stencia a clase ...
# Found in cache!
#   79 / 838 (9.4%)
#   80 / 838 (9.5%)
#   81 / 838 (9.7%)
#   82 / 838 (9.8%)
#   83 / 838 (9.9%)
# Spanish text: Inasistencia a ...ivos especiales ...
# Found in cache!
#   84 / 838 (10.0%)
#   85 / 838 (10.1%)
#   86 / 838 (10.3%)
# Spanish text: B. Calificacion... Calificaciones ...
# Found in cache!
#   87 / 838 (10.4%)
#   88 / 838 (10.5%)
#   89 / 838 (10.6%)
#   90 / 838 (10.7%)
#   91 / 838 (10.9%)
# Spanish text: 1. Notas especi...otas especiales ...
# Found in cache!
#   92 / 838 (11.0%)
#   93 / 838 (11.1%)
#   94 / 838 (11.2%)
# Spanish text: a) Incompleto...a) Incompleto ...
# Found in cache!
#   95 / 838 (11.3%)
#   96 / 838 (11.5%)
#   97 / 838 (11.6%)
# Spanish text: b) Pendiente...b) Pendiente ...
# Found in cache!
#   98 / 838 (11.7%)
#   99 / 838 (11.8%)
#  100 / 838 (11.9%)
# Spanish text: c) Pendiente di...e disciplinario ...
# Found in cache!
#  101 / 838 (12.1%)
#  102 / 838 (12.2%)
#  103 / 838 (12.3%)
# Spanish text: d) Pendiente es...diente especial ...
# Found in cache!
#  104 / 838 (12.4%)
#  105 / 838 (12.5%)
#  106 / 838 (12.6%)
#  107 / 838 (12.8%)
#  108 / 838 (12.9%)
# Spanish text: 2. Reclamos...2. Reclamos ...
# Found in cache!
#  109 / 838 (13.0%)
#  110 / 838 (13.1%)
#  111 / 838 (13.2%)
#  112 / 838 (13.4%)
#  113 / 838 (13.5%)
# Spanish text: 3. Cambio de no...tas definitivas ...
# Found in cache!
#  114 / 838 (13.6%)
#  115 / 838 (13.7%)
#  116 / 838 (13.8%)
#  117 / 838 (14.0%)
#  118 / 838 (14.1%)
# Spanish text: 4. Entrega de c... calificaciones ...
# Found in cache!
#  119 / 838 (14.2%)
#  120 / 838 (14.3%)
#  121 / 838 (14.4%)
#  122 / 838 (14.6%)
#  123 / 838 (14.7%)
# Spanish text: 5. Certificado ... calificaciones ...
# Found in cache!
#  124 / 838 (14.8%)
# Spanish text: C. Estado acadé...stado académico ...
# Found in cache!
#  125 / 838 (14.9%)
#  126 / 838 (15.0%)
#  127 / 838 (15.2%)
# Spanish text: 1. Suspensión d...n disciplinaria ...
# Found in cache!
#  128 / 838 (15.3%)
#  129 / 838 (15.4%)
#  130 / 838 (15.5%)
# Spanish text: 2. Reingreso...2. Reingreso ...
# Found in cache!
#  131 / 838 (15.6%)
#  132 / 838 (15.8%)
#  133 / 838 (15.9%)
#  134 / 838 (16.0%)
#  135 / 838 (16.1%)
# Spanish text: 3. Retiro volun...tiro voluntario ...
# Found in cache!
#  136 / 838 (16.2%)
#  137 / 838 (16.3%)
#  138 / 838 (16.5%)
#  139 / 838 (16.6%)
#  140 / 838 (16.7%)
# Spanish text: 4. Reintegro...4. Reintegro ...
# Found in cache!
#  141 / 838 (16.8%)
#  142 / 838 (16.9%)
#  143 / 838 (17.1%)
#  144 / 838 (17.2%)
#  145 / 838 (17.3%)
# Spanish text: 5. Normal...5. Normal ...
# Found in cache!
#  146 / 838 (17.4%)
# Spanish text: D. Requisitos p...los estudiantes ...
# Found in cache!
#  147 / 838 (17.5%)
#  148 / 838 (17.7%)
#  149 / 838 (17.8%)
# Spanish text: 1. Trabajo de g...e grado o tesis ...
# Found in cache!
#  150 / 838 (17.9%)
#  151 / 838 (18.0%)
#  152 / 838 (18.1%)
#  153 / 838 (18.3%)
#  154 / 838 (18.4%)
# Spanish text: 2. Requisito de...isito de inglés ...
# Found in cache!
#  155 / 838 (18.5%)
#  156 / 838 (18.6%)
#  157 / 838 (18.7%)
# Spanish text: E. Oportunidade...ades académicas ...
# Found in cache!
#  158 / 838 (18.9%)
#  159 / 838 (19.0%)
#  160 / 838 (19.1%)
# Spanish text: 1. Inscripción ...etiro de cursos ...
# Found in cache!
#  161 / 838 (19.2%)
#  162 / 838 (19.3%)
#  163 / 838 (19.5%)
# Spanish text: 2. Carga académ...Carga académica ...
# Found in cache!
#  164 / 838 (19.6%)
#  165 / 838 (19.7%)
#  166 / 838 (19.8%)
# Spanish text: 3. Doble progra... Doble programa ...
# Found in cache!
#  167 / 838 (19.9%)
#  168 / 838 (20.0%)
#  169 / 838 (20.2%)
# Spanish text: 4. Cursos duran... intersemestral ...
# Found in cache!
#  170 / 838 (20.3%)
# Spanish text: a) Cursos de va...s de vacaciones ...
# Found in cache!
#  171 / 838 (20.4%)
# Spanish text: b) Cursos de la...cuela de verano ...
# Found in cache!
#  172 / 838 (20.5%)
#  173 / 838 (20.6%)
#  174 / 838 (20.8%)
#  175 / 838 (20.9%)
#  176 / 838 (21.0%)
#  177 / 838 (21.1%)
# Spanish text: 5. Posibilidad ...ologar materias ...
# Found in cache!
#  178 / 838 (21.2%)
#  179 / 838 (21.4%)
#  180 / 838 (21.5%)
#  181 / 838 (21.6%)
#  182 / 838 (21.7%)
#  183 / 838 (21.8%)
#  184 / 838 (22.0%)
# Spanish text: 6. Posibilidad ...especialización ...
# Found in cache!
#  185 / 838 (22.1%)
#  186 / 838 (22.2%)
#  187 / 838 (22.3%)
#  188 / 838 (22.4%)
#  189 / 838 (22.6%)
# Spanish text: 7. Alumnos asis...mnos asistentes ...
# Found in cache!
#  190 / 838 (22.7%)
#  191 / 838 (22.8%)
#  192 / 838 (22.9%)
# Spanish text: # CAPÍTULO VIII...III. CONSEJERÍA ...
# Found in cache!
#  193 / 838 (23.0%)
#  194 / 838 (23.2%)
#  195 / 838 (23.3%)
#  196 / 838 (23.4%)
#  197 / 838 (23.5%)
#  198 / 838 (23.6%)
# Spanish text: # CAPÍTULO IX. ...NTOS ACADÉMICOS ...
# Found in cache!
#  199 / 838 (23.7%)
#  200 / 838 (23.9%)
#  201 / 838 (24.0%)
#  202 / 838 (24.1%)
#  203 / 838 (24.2%)
#  204 / 838 (24.3%)
# Spanish text: # CAPÍTULO X. P...NTOS EN ASUNTOS ...
# Found in cache!
#  205 / 838 (24.5%)
#  206 / 838 (24.6%)
# Spanish text: ## ACADÉMICOS Y...ADMINISTRATIVOS ...
# Found in cache!
#  207 / 838 (24.7%)
#  208 / 838 (24.8%)
#  209 / 838 (24.9%)
#  210 / 838 (25.1%)
#  211 / 838 (25.2%)
#  212 / 838 (25.3%)
# Spanish text: # CAPÍTULO XI. ...ULO XI. TÍTULOS ...
# Found in cache!
#  213 / 838 (25.4%)
#  214 / 838 (25.5%)
#  215 / 838 (25.7%)
#  216 / 838 (25.8%)
#  217 / 838 (25.9%)
#  218 / 838 (26.0%)
# Spanish text: # CAPÍTULO XII....S EXCEPCIONALES ...
# Found in cache!
#  219 / 838 (26.1%)
#  220 / 838 (26.3%)
#  221 / 838 (26.4%)
#  222 / 838 (26.5%)
# Spanish text: ## VIGENCIA...## VIGENCIA ...
# Found in cache!
#  223 / 838 (26.6%)
#  224 / 838 (26.7%)
#  225 / 838 (26.8%)
#  226 / 838 (27.0%)
# Spanish text: ## DEFINICIONES...## DEFINICIONES ...
# Found in cache!
#  227 / 838 (27.1%)
#  228 / 838 (27.2%)
#  229 / 838 (27.3%)
#  230 / 838 (27.4%)
# Spanish text: La Universidad ...con el entorno. ...
# Found in cache!
#  231 / 838 (27.6%)
#  232 / 838 (27.7%)
# Spanish text: Cuenta con estu... internacional. ...
# Found in cache!
#  233 / 838 (27.8%)
# Spanish text: ## VISIÓN...## VISIÓN ...
# Found in cache!
#  234 / 838 (27.9%)
#  235 / 838 (28.0%)
#  236 / 838 (28.2%)
# Spanish text: En el año 2020,...que desarrolla. ...
# Found in cache!
#  237 / 838 (28.3%)
# Spanish text: La Universidad ...ientes valores: ...
# Found in cache!
#  238 / 838 (28.4%)
# Spanish text: Excelencia: Com... a la sociedad. ...
# Found in cache!
#  239 / 838 (28.5%)
# Spanish text: Integridad: Rec...ignidad humana. ...
# Found in cache!
#  240 / 838 (28.6%)
# Spanish text: Libertad: Uso d... se debe hacer. ...
# Found in cache!
#  241 / 838 (28.8%)
#  242 / 838 (28.9%)
# Spanish text: Solidaridad: Ad...dades de otros. ...
# Found in cache!
#  243 / 838 (29.0%)
# Spanish text: La Universidad ...de pensamiento. ...
# Found in cache!
#  244 / 838 (29.1%)
# Spanish text: La Universidad ...e la comunidad. ...
# Found in cache!
#  245 / 838 (29.2%)
# Spanish text: Es función esen...io profesional. ...
# Found in cache!
#  246 / 838 (29.4%)
# Spanish text: La Universidad ... interés común. ...
# Found in cache!
#  247 / 838 (29.5%)
# Spanish text: El presente reg...nvivencia en la ...
# Found in cache!
#  248 / 838 (29.6%)
#  249 / 838 (29.7%)
#  250 / 838 (29.8%)
#  251 / 838 (30.0%)
# Spanish text: Universidad....Universidad. ...
# Found in cache!
#  252 / 838 (30.1%)
#  253 / 838 (30.2%)
#  254 / 838 (30.3%)
# Spanish text: # CAPÍTULO I...# CAPÍTULO I ...
# Found in cache!
#  255 / 838 (30.4%)
#  256 / 838 (30.5%)
# Spanish text: ## CAMPO DE APL...O DE APLICACIÓN ...
# Found in cache!
#  257 / 838 (30.7%)
#  258 / 838 (30.8%)
# Spanish text: El presente reg...d de los Andes. ...
# Found in cache!
#  259 / 838 (30.9%)
# Spanish text: ART. 1º. Para t...versidad de los ...
# Found in cache!
#  260 / 838 (31.0%)
# Spanish text: Andes toda pers...es situaciones: ...
# Found in cache!
#  261 / 838 (31.1%)
# Spanish text: a) Quien se enc...la institución. ...
# Found in cache!
#  262 / 838 (31.3%)
# Spanish text: b) Quien se enc...amas regulares. ...
# Found in cache!
#  263 / 838 (31.4%)
# Spanish text: c) Aquel a quie...por ventanilla. ...
# Found in cache!
#  264 / 838 (31.5%)
# Spanish text: d) Quien se enc...iplinariamente. ...
# Found in cache!
#  265 / 838 (31.6%)
#  266 / 838 (31.7%)
# Spanish text: ART. 2º. Al mat... institucional. ...
# English text: "ART. 2. Upon e...onal web page."
#  267 / 838 (31.9%)
#  268 / 838 (32.0%)
#  269 / 838 (32.1%)
# Spanish text: # CAPÍTULO II...# CAPÍTULO II ...
# English text: # CHAPTER II...# CHAPTER II
#  270 / 838 (32.2%)
#  271 / 838 (32.3%)
# Spanish text: ## ORGANIZACIÓN...IZACIÓN GENERAL ...
# English text: ## GENERAL ORGA...AL ORGANIZATION
#  272 / 838 (32.5%)
#  273 / 838 (32.6%)
#  274 / 838 (32.7%)
#  275 / 838 (32.8%)
# Spanish text: ART. 3º. La Uni...ral, un Consejo ...
# English text: "ART. 3º. The U...and a Council."
#  276 / 838 (32.9%)
#  277 / 838 (33.1%)
#  278 / 838 (33.2%)
# Spanish text: # CAPÍTULO V. D...ECHOS Y DEBERES ...
# Found in cache!
#  279 / 838 (33.3%)
#  280 / 838 (33.4%)
#  281 / 838 (33.5%)
#  282 / 838 (33.7%)
# Spanish text: Académico, los ... y reglamentos. ...
# English text: "Academically, ...d regulations."
#  283 / 838 (33.8%)
#  284 / 838 (33.9%)
#  285 / 838 (34.0%)
# Spanish text: # CAPÍTULO III...# CAPÍTULO III ...
# English text: # CHAPTER III...# CHAPTER III
#  286 / 838 (34.1%)
#  287 / 838 (34.2%)
# Spanish text: ## INGRESO Y PE...O Y PERMANENCIA ...
# English text: ## ADMISSION AN...N AND RETENTION
#  288 / 838 (34.4%)
#  289 / 838 (34.5%)
# Spanish text: A. Ingreso regu...Ingreso regular ...
# English text: "Regular Admiss...ular Admission"
#  290 / 838 (34.6%)
# Spanish text: ART. 4º. El ing...tes requisitos: ...
# English text: ART. 4. Admissi...rsity setting.)
#  291 / 838 (34.7%)
# Spanish text: a) Haber termin...lo profesional. ...
# English text: a) Having compl...ssional degree.
#  292 / 838 (34.8%)
# Spanish text: b) Cumplir sati...ere pertinente. ...
# English text: b) Satisfactori...iders relevant.
#  293 / 838 (35.0%)
# Spanish text: ART. 5º. Las so...r, como mínimo: ...
# English text: "ART. 5. Applic... at a minimum:"
#  294 / 838 (35.1%)
# Spanish text: a) Formulario d...e diligenciado. ...
# English text: The translation...lication form."
#  295 / 838 (35.2%)
# Spanish text: b) Copia del di...do profesional. ...
# English text: A copy of the d...ssional degree.
#  296 / 838 (35.3%)
#  297 / 838 (35.4%)
#  298 / 838 (35.6%)
#  299 / 838 (35.7%)
# Spanish text: ART. 6º. No se ...ará suspendido. ...
# English text: "ART. 6. The ad...er suspension."
#  300 / 838 (35.8%)
# Spanish text: Si un estudiant...rial académico: ...
# English text: If a student wh...t you provided)
#  301 / 838 (35.9%)
# Spanish text: a) Empezar con ...émico anterior. ...
# English text: 'a) To start wi...demic program.'
#  302 / 838 (36.0%)
# Spanish text: b) Conservar lo...gundo programa. ...
# English text: b) To keep the ...second program.
#  303 / 838 (36.2%)
# Spanish text: ART. 7º. La Uni...de la libertad. ...
# English text: "The University... imprisonment."
#  304 / 838 (36.3%)
# Spanish text: El Consejo Acad...e la matrícula. ...
# English text: The translation...of enrollment."
#  305 / 838 (36.4%)
# Spanish text: Si el interesad...cionado órgano. ...
# English text: If the interest...mentioned body.
#  306 / 838 (36.5%)
#  307 / 838 (36.6%)
# Spanish text: Contra las deci...de la decisión. ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 9
#       7 for i, line in enumerate(input_lines):
#       8     print(f"{i+1:4d} / {n_lines} ({100.0 * (i+1)/n_lines:.1f}%)")
# ----> 9     line_translation = translator.translate(line)
#      10     print(line_translation, file=f_out, flush=True, end="")
#
# File ~/git/llm_finetunning/notebooks/../src/translation.py:61, in GroqTranslator.translate(self, spanish_text, verbose)
#      58     translation_text = chat_completion.choices[0].message.content
#      59     self.cache[spanish_text] = translation_text
# ---> 61     time.sleep(self.pause_secs)
#      62 except Exception as exc:
#      63     raise exc
#
# KeyboardInterrupt:

# %%
translator.cache[""] = ""
